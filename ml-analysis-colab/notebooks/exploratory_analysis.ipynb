# %% [markdown]
# # EDA - Heart Disease Dataset
#
# Notebook para realizar el análisis exploratorio de datos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://raw.githubusercontent.com/ChiragSahni/Data-Science-Heart-Disease/master/heart.csv'
df = pd.read_csv(url)
df.head()

# %%
# Información básica
df.info()

df.describe()

# %%
# Visualizaciones de ejemplo
import seaborn as sns
plt.figure(figsize=(6,4))
sns.countplot(x='target', data=df)
plt.show()
